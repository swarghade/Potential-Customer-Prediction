# %%
import pandas as pd
import numpy as np

import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# # Reading the file

# %%
df = pd.read_csv('Social_Network_Ads.csv')

# %%
df.head()
# Out:
#     User ID  Gender  Age  EstimatedSalary  Purchased
# 0  15624510    Male   19            19000          0
# 1  15810944    Male   35            20000          0
# 2  15668575  Female   26            43000          0
# 3  15603246  Female   27            57000          0
# 4  15804002    Male   19            76000          0

# %%
df['Gender'].replace(['Male','Female'],[0,1],inplace=True) ##Male value as 0 and Female as 1

# %%
df.head()
# Out:
#     User ID  Gender  Age  EstimatedSalary  Purchased
# 0  15624510       0   19            19000          0
# 1  15810944       0   35            20000          0
# 2  15668575       1   26            43000          0
# 3  15603246       1   27            57000          0
# 4  15804002       0   19            76000          0

# %%
df.dropna()
# Out:
#       User ID  Gender  Age  EstimatedSalary  Purchased
# 0    15624510       0   19            19000          0
# 1    15810944       0   35            20000          0
# 2    15668575       1   26            43000          0
# 3    15603246       1   27            57000          0
# 4    15804002       0   19            76000          0
# ..        ...     ...  ...              ...        ...
# 395  15691863       1   46            41000          1
# 396  15706071       0   51            23000          1
# 397  15654296       1   50            20000          1
# 398  15755018       0   36            33000          0
# 399  15594041       1   49            36000          1
#
# [400 rows x 5 columns]

# %%
df.isnull().values.any() ## NO NULL VALUES FOUND
# Out:
# False

# %%
df.dtypes
# Out:
# Gender             int64
# Age                int64
# EstimatedSalary    int64
# Purchased          int64
# dtype: object

# %% [markdown]
# # Pair Plot & Distribution Plot

# %%
sns.pairplot(df,hue='Gender')

# %%
sns.distplot(df.Purchased, color = 'Teal')

# %% [markdown]
# # Estimated Salary

# %%
sns.violinplot(x='day',y='total_bill',data=tips,hue='sex',split='hue')
sns.swarmplot(x='day',y='total_bill',data=tips,color='white')

# %% [markdown]
# # Distribution of Purchase.

# %%
plt.hist(x="Purchased", data=df, color='Teal', rwidth= 1);
plt.title('Distribution of Purchase');
plt.ylabel('Count');
plt.xlabel('Purchase');

# %%
plt.figure(figsize=(10,5))
b_size = np.arange(10000,160000,5000)
plt.hist(x="EstimatedSalary", data = df, bins= b_size, rwidth = 0.5, color='teal')
plt.title('Customers vs Salary');
plt.ylabel('Count of Customers');
plt.xlabel('Salary');

# %% [markdown]
# # Average Salary

# %%
df.EstimatedSalary.mean()
# Out:
# 69742.5

# %% [markdown]
# # Understanding what Age Group Orders more.

# %%
b_size = np.arange(18,65,2.5)
plt.figure(figsize=(10,3))
plt.hist(x='Age',data = df, bins = b_size, rwidth = 0.5,color='teal')
# Out:
# (array([19.,  9., 21., 29., 33., 20., 47., 32., 43., 32., 12., 26., 28.,
#          9., 12.,  8., 20.,  0.]),
#  array([18. , 20.5, 23. , 25.5, 28. , 30.5, 33. , 35.5, 38. , 40.5, 43. ,
#         45.5, 48. , 50.5, 53. , 55.5, 58. , 60.5, 63. ]),
#  <a list of 18 Patch objects>)

# %%
## Dropping Duplicates and Non Essential Values
df.drop_duplicates(inplace= True)
df.drop(columns=['User ID'],inplace = True)

# %%
## Check if Outliers are present in the data.
from scipy import stats
outliers_ES = np.abs(stats.zscore(df['EstimatedSalary']))
outliers_Age = np.abs(stats.zscore(df['Age']))
print(np.where(outliers_ES > 3))
print(np.where(outliers_Age > 3))
# Out:
# (array([], dtype=int64),)
# (array([], dtype=int64),)

# %%
df.shape
# Out:
# (400, 4)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 400 entries, 0 to 399
# Data columns (total 4 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Gender           400 non-null    int64
#  1   Age              400 non-null    int64
#  2   EstimatedSalary  400 non-null    int64
#  3   Purchased        400 non-null    int64
# dtypes: int64(4)
# memory usage: 15.6 KB

# %%
a = df.groupby(['Gender', 'Age','Purchased'])
a.first()
# Out:
#                       EstimatedSalary
# Gender Age Purchased
# 0      18  0                    82000
#        19  0                    19000
#        20  0                    86000
#        21  0                    72000
#        22  0                    18000
# ...                               ...
# 1      57  1                   122000
#        58  1                   101000
#        59  0                    83000
#            1                    76000
#        60  1                   108000
#
# [119 rows x 1 columns]

# %% [markdown]
# # Standardizing Dataset

# %%
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
scaler.fit(df.drop('Purchased',axis=1))
# Out:
# StandardScaler(copy=True, with_mean=True, with_std=True)

# %%
scaled_features = scaler.transform(df.drop('Purchased',axis=1))
df_feat = pd.DataFrame(scaled_features,columns=df.columns[:-1])

# %%
df_feat.head()
# Out:
#      Gender       Age  EstimatedSalary
# 0 -1.020204 -1.781797        -1.490046
# 1 -1.020204 -0.253587        -1.460681
# 2  0.980196 -1.113206        -0.785290
# 3  0.980196 -1.017692        -0.374182
# 4 -1.020204 -1.781797         0.183751

# %% [markdown]
# # Training Dataset and applying KNN

# %%
from sklearn.model_selection import train_test_split

# %%
X = df_feat
y = df['Purchased']

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.30, random_state=42)

# %%
from sklearn.neighbors import KNeighborsClassifier

# %%
knn = KNeighborsClassifier(n_neighbors=10)

# %%
knn.fit(X_train,y_train)
# Out:
# KNeighborsClassifier(algorithm='auto', leaf_size=30, metric='minkowski',
#                      metric_params=None, n_jobs=None, n_neighbors=10, p=2,
#                      weights='uniform')

# %%
pred = knn.predict(X_test)

# %%
from sklearn.metrics import classification_report,confusion_matrix

# %%
print(confusion_matrix(y_test,pred))
print(classification_report(y_test,pred))
# Out:
# [[69  4]
#  [ 4 43]]
#               precision    recall  f1-score   support
#
#            0       0.95      0.95      0.95        73
#            1       0.91      0.91      0.91        47
#
#     accuracy                           0.93       120
#    macro avg       0.93      0.93      0.93       120
# weighted avg       0.93      0.93      0.93       120

# %%
error_rate = []

for i in range(1,25):
    knn = KNeighborsClassifier(n_neighbors=i)
    knn.fit(X_train,y_train)
    pred_i = knn.predict(X_test)
    error_rate.append(np.mean(pred_i != y_test))
    set(y_test) - set(pred)

# %%
plt.figure(figsize=(10,6))
plt.plot(range(1,25),error_rate,color='b',linestyle='dashed',marker='o',markerfacecolor='red',markersize=10)
plt.title('Error Rate vs K Values')
plt.xlabel('K Values')
plt.ylabel('Error Rate')
# Out:
# Text(0, 0.5, 'Error Rate')

# %%
knn = KNeighborsClassifier(n_neighbors=10)
knn.fit(X_train,y_train)
pred = knn.predict(X_test)
print(confusion_matrix(y_test,pred))
print('\n')
print(classification_report(y_test,pred))
# Out:
# [[69  4]
#  [ 4 43]]
#
#
#               precision    recall  f1-score   support
#
#            0       0.95      0.95      0.95        73
#            1       0.91      0.91      0.91        47
#
#     accuracy                           0.93       120
#    macro avg       0.93      0.93      0.93       120
# weighted avg       0.93      0.93      0.93       120

# %%
from sklearn.metrics import accuracy_score
print(accuracy_score(y_test,pred))
# Out:
# 0.9333333333333333

# %% [markdown]
# # Decision Tree

# %%
plt.figure(figsize=(10,4))
sns.scatterplot(x='EstimatedSalary',y='Age',hue='Purchased',data=df)
plt.title('Estimated Salary vs Age')
# Out:
# Text(0.5, 1.0, 'Estimated Salary vs Age')

# %%
from sklearn.tree import DecisionTreeClassifier

decision_tree = DecisionTreeClassifier(criterion='entropy', random_state=4)
decision_tree.fit(X_train,y_train)
dtpred = decision_tree.predict(X_test)

# %%
print(confusion_matrix(y_test,pred))
print('\n')
print(classification_report(y_test,pred))
# Out:
# [[69  4]
#  [ 4 43]]
#
#
#               precision    recall  f1-score   support
#
#            0       0.95      0.95      0.95        73
#            1       0.91      0.91      0.91        47
#
#     accuracy                           0.93       120
#    macro avg       0.93      0.93      0.93       120
# weighted avg       0.93      0.93      0.93       120

# %%
from sklearn.metrics import accuracy_score
from sklearn.model_selection import cross_val_score
print(accuracy_score(y_test,pred))
# Out:
# 0.9333333333333333
